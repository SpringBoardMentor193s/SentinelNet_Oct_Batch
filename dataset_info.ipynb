# %% [markdown]
# Dataset 1:- NSL KDD

# %%
import pandas as pd

# %%
df_train = pd.read_csv("kdd_train.csv")
df_test = pd.read_csv("kdd_test.csv")

# %%
print(f""" 
---Data set train summary---

Size                : {df_train.size}
Shape               : {df_train.shape}

Null Values:
{df_train.isna().sum()}

Total Missing (%)   : {(df_train.isnull().sum().sum() / df_train.size) * 100:.2f}%

Preview:
{df_train.head()}

""")
# Out:
#
# ---Data set train summary---
#
# Size                : 5290866
# Shape               : (125973, 42)
#
# Null Values:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# ...

# %%
print(f"""
---Dataset Test Summary---

Size                : {df_train.size}
Shape               : {df_train.shape}

Null Values:
{df_train.isna().sum()}

Total Missing (%)   : {(df_train.isnull().sum().sum() / df_train.size) * 100:.2f}%

Preview:
{df_train.head()}

""")
# Out:
# ---Dataset Test Summary---
#
# Size                : 5290866
# Shape               : (125973, 42)
#
# Null Values:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# ...

# %% [markdown]
# Dataset 2 :- CICDS

# %%
df = pd.read_csv("Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv")

# %%
df.head(4)
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              54865               3                   2
# 1              55054             109                   1
# 2              55055              52                   1
# 3              46236              34                   1
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        1                            6
# 2                        1                            6
# 3                        1                            6
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       6
# 1                             6                       6
# 2                             6                       6
# 3                             6                       6
#
#     Fwd Packet Length Min   Fwd Packet Length Mean   Fwd Packet Length Std  \
# ...

# %%
print(f"""
--- Dataset CICDS Summary ---

Size                : {df.size}
Shape               : {df.shape}

Null Values:
{df.isna().sum()}

Total Missing (%)   : {(df.isnull().sum().sum() / df.size) * 100:.2f}%

Preview:
{df.head()}

""")

# %%
NSL-KDD

# %%
========== FINAL MODEL PERFORMANCE TABLE ==========

                 Model  Train_Accuracy  Test_Accuracy       Gap  Precision  \
0  Logistic Regression        0.909584       0.954312 -0.044728   0.951841
1        Decision Tree        0.912838       0.997605 -0.084766   1.000000
2        Random Forest        0.927969       0.997605 -0.069636   0.997663
3    Gradient Boosting        0.926556       0.980350 -0.053794   0.978970

     Recall  F1_Score    TN   FP   FN     TP
0  0.968752  0.960222  9082  629  401  12432
1  0.995792  0.997892  9711    0   54  12779
2  0.998130  0.997897  9681   30   24  12809
3  0.986675  0.982807  9439  272  171  12662

# %%
Model summary (Name, Weighted F1, Accuracy, ROC-AUC macro OVR):
('LogisticRegression', 0.9920706005486545, 0.9921254842192163, np.float64(nan))
('RandomForest', 0.9989387527272675, 0.999015685527402, np.float64(nan))
('GradientBoosting', 0.3686867518987852, 0.3541309455769353, np.float64(nan))
('KNN', 0.9974807505103988, 0.997586841938147, np.float64(nan))
('SVC_prob', 0.9966626553421395, 0.9967930399441164, np.float64(nan))
('XGBoost', 0.9990883144341808, 0.9991426938464469, np.float64(nan))

# %%
CICIDS

# %%
========== FINAL MODEL PERFORMANCE ==========

              Model  Accuracy  Sensitivity  Specificity  F1 Score      AUC
Logistic Regression  0.994422     0.611253     0.998386  0.691751 0.987072
      Decision Tree  0.999738     0.989770     0.999841  0.987245 0.994806
      Random Forest  0.999424     0.943734     1.000000  0.971053 0.999943
  Gradient Boosting  0.999738     0.982097     0.999921  0.987147 0.999993

# %%
Model Summary (Name, F1, Accuracy, ROC-AUC):
('LogisticRegression', 0.9985470101585476, 0.9985470524655811, nan)
('RandomForest', 0.9999291248538179, 0.9999291245105162, nan)
('GradientBoosting', 0.9999114058527381, 0.9999114056381452, nan)
('KNN', 0.9997342162704804, 0.9997342169144355, nan)
('SVC_prob', 0.9985292728858888, 0.9985293335932102, nan)
('XGBoost', 0.9999822811705477, 0.999982281127629, nan)

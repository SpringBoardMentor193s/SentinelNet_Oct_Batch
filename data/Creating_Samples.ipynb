# %%
import pandas as pd

# %%
df = pd.read_csv("kdd_train_final.csv")

# %%
df.columns
# Out:
# Index(['duration', 'src_bytes', 'dst_bytes', 'wrong_fragment', 'hot',
#        'logged_in', 'num_compromised', 'root_shell', 'num_root',
#        'num_file_creations', 'num_shells', 'num_access_files',
#        'is_guest_login', 'count', 'srv_count', 'serror_rate',
#        'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
#        'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate', 'protocol_type_encoded', 'service_encoded',
#        'flag_encoded', 'attack_binary'],
#       dtype='object')

# %%
df1 = pd.read_csv("kdd_test_final.csv")

# %%
df1.columns
# Out:
# Index(['duration', 'src_bytes', 'dst_bytes', 'wrong_fragment', 'hot',
#        'logged_in', 'num_compromised', 'root_shell', 'num_root',
#        'num_file_creations', 'num_shells', 'num_access_files',
#        'is_guest_login', 'count', 'srv_count', 'serror_rate',
#        'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
#        'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate', 'protocol_type_encoded', 'service_encoded',
#        'flag_encoded', 'attack_binary'],
#       dtype='object')

# %%
df1.drop(labels=['attack_binary'],axis=1,inplace=True)

# %%
random_rows_df = df1.sample(n=5, random_state=42)

# %%
random_rows_df
# Out:
#        duration  src_bytes  dst_bytes  wrong_fragment  hot  logged_in  \
# 6186          0        326        501               0    0          1
# 247           0          0          0               0    0          0
# 4343       7408          0         44               0    0          0
# 17527         0          0          0               0    0          0
# 13123         0       5929          0               0    0          0
#
#        num_compromised  root_shell  num_root  num_file_creations  ...  \
# 6186                 0           0         0                   0  ...
# 247                  0           0         0                   0  ...
# 4343                 0           0         0                   0  ...
# 17527                0           0         0                   0  ...
# 13123                0           0         0                   0  ...
#
#        dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 6186                     0.00                         0.06
# ...

# %%
random_rows_df.to_csv("sample_test.csv",index=False)

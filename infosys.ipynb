# %% [markdown]
# <a href="https://colab.research.google.com/github/SpringBoardMentor193s/SentinelNet_Oct_Batch/blob/ganesh/infosys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_train = pd.read_csv("/content/kdd_train (1).csv")

# %%
# !wget http://kdd.ics.uci.edu/databases/kddcup99/kddcup.data.gz
# !wget http://kdd.ics.uci.edu/databases/kddcup99/kddcup.testdata.unlabeled.gz
# Out:
# --2025-11-10 15:07:41--  http://kdd.ics.uci.edu/databases/kddcup99/kddcup.data.gz
# Resolving kdd.ics.uci.edu (kdd.ics.uci.edu)... 128.195.1.94
# Connecting to kdd.ics.uci.edu (kdd.ics.uci.edu)|128.195.1.94|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18115902 (17M) [application/x-gzip]
# Saving to: ‘kddcup.data.gz’
#
# kddcup.data.gz      100%[===================>]  17.28M  15.5MB/s    in 1.1s
#
# 2025-11-10 15:07:43 (15.5 MB/s) - ‘kddcup.data.gz’ saved [18115902/18115902]
#
# --2025-11-10 15:07:43--  http://kdd.ics.uci.edu/databases/kddcup99/kddcup.testdata.unlabeled.gz
# Resolving kdd.ics.uci.edu (kdd.ics.uci.edu)... 128.195.1.94
# Connecting to kdd.ics.uci.edu (kdd.ics.uci.edu)|128.195.1.94|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11234858 (11M) [application/x-gzip]
# Saving to: ‘kddcup.testdata.unlabeled.gz’
#
# kddcup.testdata.unl 100%[===================>]  10.71M  5.98MB/s    in 1.8s
#
# ...

# %%
df_test = pd.read_csv("/content/kdd_test (1).csv")

# %%
print(f'''
Dataset Train-\n
size:-{df_train.size}\n
shape:-{df_train.shape}\n
Null values:-
{df_train.isna().sum()}\n\n
total missing value percentage:-{(df_train.isnull().sum().sum()/df_train.size ) * 100}%

preview:-\n
{df_train.head()}
''')
# Out:
# Dataset Train-
#
# size:-5021436
#
# shape:-(119558, 42)
#
# Null values:-
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     1
# su_attempted                   1
# num_root                       1
# num_file_creations             1
# num_shells                     1
# num_access_files               1
# num_outbound_cmds              1
# is_host_login                  1
# is_guest_login                 1
# count                          1
# srv_count                      1
# serror_rate                    1
# srv_serror_rate                1
# ...

# %%
print(f'''
Dataset Test-\n
size:-{df_test.size}\n
shape:-{df_test.shape}\n
Null values:-
{df_test.isna().sum()}\n\n
total missing value percentage:-{(df_test.isnull().sum().sum()/df_test.size ) * 100}%

preview:-\n
{df_test.head()}
''')
# Out:
# Dataset Test-
#
# size:-946848
#
# shape:-(22544, 42)
#
# Null values:-
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel("summary.xlsx", engine="openpyxl")
df
# Out:
#                      Model  Train_Accuracy  Test_Accuracy       Gap  \
# 0  Linear Regression (OLS)        0.953902       0.896247  0.057654
# 1   Gradient Descent (SGD)        0.498905       0.435504  0.063401
# 2      Logistic Regression        0.955730       0.893497  0.062233
# 3   Naïve Bayes (Gaussian)        0.890262       0.852200  0.038062
# 4            Decision Tree        0.976027       0.916829  0.059198
# 5            Random Forest        0.985707       0.919402  0.066305
# 6                  XGBoost        0.993225       0.928540  0.064685
# 7         SVM (RBF Kernel)        0.988779       0.925124  0.063655
#
#    Precision    Recall  F1_Score     TN    FP    FN    TP
# 0   0.955007  0.832198  0.889383  10802   443  1896  9403
# 1   0.449343  0.560138  0.498661   3489  7756  4970  6329
# 2   0.949666  0.831578  0.886708  10747   498  1903  9396
# 3   0.902089  0.790955  0.842875  10275   970  2362  8937
# 4   0.973092  0.857775  0.911802  10977   268  1607  9692
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.bar(df['Model'], df['Test_Accuracy'])
plt.xlabel("Models")
plt.ylabel("Test Accuracy")
plt.title("Model Comparison – Test Accuracy")
plt.xticks(rotation=45)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

metrics = ['Test_Accuracy', 'Precision', 'Recall', 'F1_Score']

x = np.arange(len(df['Model']))
width = 0.2

plt.figure(figsize=(12,6))

for i, metric in enumerate(metrics):
    plt.bar(x + i*width, df[metric], width, label=metric)

plt.xticks(x + width, df['Model'], rotation=45)
plt.ylabel("Score")
plt.title("Model Performance Comparison")
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(df['Model'], df['Test_Accuracy'], marker='o', label='Accuracy')
plt.plot(df['Model'], df['Precision'], marker='o', label='Precision')
plt.plot(df['Model'], df['Recall'], marker='o', label='Recall')
plt.plot(df['Model'], df['F1_Score'], marker='o', label='F1 Score')

plt.xlabel("Models")
plt.ylabel("Score")
plt.title("Model Performance Trend")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

metrics = ['Test_Accuracy', 'Precision', 'Recall', 'F1_Score']
N = len(metrics)

angles = np.linspace(0, 2*np.pi, N, endpoint=False).tolist()
angles += angles[:1]

plt.figure(figsize=(7,7))

for i, row in df.iterrows():
    values = row[metrics].tolist()
    values += values[:1]
    plt.polar(angles, values, marker='o', label=row['Model'])

plt.xticks(angles[:-1], metrics)
plt.title("Model Comparison Radar Chart")
plt.legend(loc='upper right', bbox_to_anchor=(1.25, 1.05))
plt.show()

# %%
plt.figure(figsize=(12,6))

cm_labels = ['TN', 'FP', 'FN', 'TP']

for cm in cm_labels:
    plt.plot(df['Model'], df[cm], marker='o', label=cm)

plt.xticks(rotation=45)
plt.ylabel("Count")
plt.title("Confusion Matrix Comparison")
plt.legend()
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_excel("summary.xlsx")   # now working

plt.figure(figsize=(12, 6))
plt.bar(df["Model"], df["Train_Accuracy"], label="Train Accuracy")
plt.bar(df["Model"], df["Test_Accuracy"], label="Test Accuracy", alpha=0.7)
plt.xticks(rotation=45)
plt.ylabel("Accuracy")
plt.title("Train vs Test Accuracy Comparison")
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))

x = range(len(df))
width = 0.25

plt.bar([p - width for p in x], df['Precision'], width=width, label='Precision')
plt.bar(x, df['Recall'], width=width, label='Recall')
plt.bar([p + width for p in x], df['F1_Score'], width=width, label='F1 Score')

plt.xticks(x, df['Model'], rotation=45)
plt.ylabel("Scores")
plt.title("Precision, Recall, F1 Score Comparison")
plt.legend()
plt.tight_layout()
plt.show()
